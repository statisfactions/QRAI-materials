# %% [markdown]
# # Part B: Head Circumference

# %% [markdown]
# How big is a head all the way around?  Well, we can always measure it!
#
# 1. Below, type the numbers that we produced in class for the Ethan's head circumference.  You don't need to format it in any particular way, just write the 5 numbers down.

# %% [markdown]
# 2. Describe the 5 measurements that we produced. What do they tell you about the true circumference of the volunteer's head?

# %% [markdown]
# 3. How could you estimate the true circumference of Ethan's head from the numbers provided? Compute the estimate in the code block below, using Python as your calculator.

# %%
# Your code here (if you want to calculate something -- nothing fancy, just use as a calculator)

# %% [markdown]
# # Part C: Sticky Centers

# %% [markdown]
# ## C.1 Means

# %% [markdown]
# In your small group, you will take 9 Sticky Notes and stack them on the Age Scale that you were provided as a handout to form a dot plot according to the directions provided. Each dot plot will be created so that the 9 ages (Sticky Notes) have a mean of 21 years.
#
# 1.	Start by stacking all the sticky notes so that they are all 21.

# %% [markdown]
# 2.	Move one Sticky Note to 24 years. How can you move one or more of the other Sticky Notes so that you keep the mean at 21 years? Is there more than one way to do this? Explain.

# %% [markdown]
# 3.	Next, move one Sticky Note to 17 years. Describe what else you had to do to keep the mean at 21 years.

# %% [markdown]
# 4.	Next, move all the Sticky Notes so that none of the ages are 21 years, yet the mean age is still 21 years. Compute the mean age in Python to check that it is still 21.

# %%
# Your code here

# %% [markdown]
# 5. Now, move the sticky notes so that they are more spread out than they were in Question #4, maintaining the mean of 21.  Compute the mean age in Python to check that it is still 21.

# %% [markdown]
# ## C.2 Medians

# %% [markdown]
# We'll continue playing with sticky notes -- but now looking at medians.
#
# 1.	Adjust your plot from the prior question so that the *median* is 21 years. What did you have to do to achieve a median of 21?

# %% [markdown]
# 2.	Now change one of the values that is currently higher than 21 years. If you move it higher or lower than it is right now, but keep the value higher than 21 years, is the median affected? Explain.

# %% [markdown]
# 4.	Now move all of the values that are lower than 21 years so that each one has a lower value than it does currently. Did this have any effect on the median? Explain.

# %% [markdown]
# 5.	Change the median by moving the *minimum* number of values. In other words, try to change the median by moving as few data values as possible, and describe what you did. List the 9 data values before and after your change.

# %% [markdown]
# 6. Was it harder to change the median or the mean?  Explain.

# %% [markdown]
# # Credits
#
# Sticky Centers activity adapted for Fulbright & Google Colab by Ethan Brown from Garfield, J., Zieffler, A., & Lane-Getaz, S. (2005).  EPSY 3264 Course Packet (The AIMS curriculum), University of Minnesota, Minneapolis, MN.
